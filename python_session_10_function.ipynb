# %% [markdown]
# ** functions or methods **
#
# - reuse of the code

# %% [markdown]
# - functions without arguments
#
# -  functions with arguments
#
# - functions with default arguments
#
# - global variable vs local variable
#
# - function with return statement
#
# - function with kwargs
#
# - functions in functions

# %%
# syntax 

def <function name>():
    <write your code here>

# %% [markdown]
# ## funtions without arguments
#
# - the functions we defined does not have any value or variable
#
# - these also called as arguments or parameters
#
# - simply it is a empty bracket

# %%
n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
add=n1+n2
print(f"the addition of{n1},{n2}is :{add}")
# Out:
# enter the n1: 20
# enter the n2: 30
# the addition of20,30is :50

# %%
def addition():
    n1=eval(input('enter the n1:'))
    n2=eval(input('enter the n2:'))
    add=n1+n2
    print(f"the addition of{n1},{n2}is :{add}")

# %%
# function is ready 
# creating a function it will not give the answer 
# you need to call the cunction 
addition()
# Out:
# enter the n1: 20
# enter the n2: 30
# the addition of20,30is :50

# %% [markdown]
# ## note
#
# - while calling the function we need to use the function name
#
# - also we need to provides brackets
#
# - in pyhtno brackets indicates it is a function or methods
#
# - if we miss the brackets, it wil,it display as
#
#   - function
#
#   - bound method

# %% [markdown]
# ## note
#
# - once we create the function we can use anywhere in the notebook
#
# - if we want to use in another notebook
#
# - we need to create as package(OPPS)

# %%
addition1()
def addition():
    n1=eval(input('enter the n1:'))
    n2=eval(input('enter the n2:'))
    add=n1+n2
    print(f"the addition of{n1},{n2}is :{add}")

# the above code will give the error 
# before call the function first we need to define the function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 addition1()
#       2 def addition():
#       3     n1=eval(input('enter the n1:'))
#
# NameError: name 'addition1' is not defined

# %%
def addition():
    n1=eval(input('enter the n1:'))
    n2=eval(input('enter the n2:'))
    add=n1+n2
    print(f"the addition of{n1},{n2}is :{add}")

addition 1()
# Out:
#   Cell In[34], line 7
#     addition 1()
#              ^
# SyntaxError: invalid syntax

# %%
def average():
    n1=eval(input('enter the n1:'))
    n2=eval(input('enter the n2:'))
    n3=eval(input('enter the n3:'))
    avg=(n1+n2+n3)/3
    print(f"the averege of {n1},{n2},{n3} is:{avg}")

average()
# Out:
# enter the n1: 11
# enter the n2: 12
# enter the n3: 12
# the averege of 11,12,12 is:11.666666666666666

# %%
def triangle():
    b=eval(input('enter the breath:'))
    h=eval(input('enter the height:'))
    area=0.5*b*h
    print(f"the area of right angle triangle is :{area}")
triangle()
# Out:
# enter the breath: 33
# enter the height: 12
# the area of right angle triangle is :198.0

# %%
def area_of_circle():
    pi=eval(input('enter the pi value:'))
    r=eval(input('enter the radius:'))
    area=pi*r*r
    print(f"the area of circle is :{area}")

area_of_circle()
# Out:
# enter the pi value: 3.14
# enter the radius: 3
# the area of circle is :28.259999999999998

# %% [markdown]
# ## note
#
# - variable names should not equalto function names

# %%
def AVERAGE():
   try: 
        n1=eval(input('enter the n1:'))
        n2=eval(input('enter the n2:'))
        n3=eval(input('enter the n3:'))
        avg=(n1+n2+n3)/3
        print(f"the averege of {n1},{n2},{n3} is:{avg}")

   except exception as e:
         print(e)

AVERAGE()
# Out:
# enter the n1: 10
# enter the n2: 6
# enter the n3: 8
# the averege of 10,6,8 is:8.0

# %%
try:
def averageee():
    n1=eval(input('enter the n1:'))
    n2=eval(input('enter the n2:'))
    n3=eval(input('enter the n3:'))
    avg=(n1+n2+n3)/3
    print(f"the averege of {n1},{n2},{n3} is:{avg}")

except exception  as e:
    print(e)

averageee()
# Out:
#   Cell In[69], line 2
#     def averageee():
#     ^
# IndentationError: expected an indented block after 'try' statement on line 1

# %% [markdown]
# ## note
#
# - always give try and except for only code
#
# - not for function
#
# - inside the function write try-except

# %%
def bill():
    billamount=eval(input("enter the bill amount:"))
    tipamount=eval(input("enter the tip amount:"))
    totalbill= billamount+tipamount
    print(f"the total bill is:{totalbill}")
bill()
# Out:
# enter the bill amount: 120
# enter the tip amount: 30
# the total bill is:150

# %%
bill()
# Out:
# enter the bill amount: 2000
# enter the tip amount: 30
# the total bill is:2030

# %% [markdown]
# ## note
#
# - when we define the function, it will not give any error or any answer
#
# - if we want to see any error ar any answer we need to

# %%
# with out arguments 
#with arguments 
# default argumments

# %%
import random
num1=random.randint(1,10)
num2=eval(input('enter the num2:'))
if num1==num2:
    print("won")
else:
    print("loss")
# Out:
# enter the num2: 3
# won

# %%
def game1():
    num1=random.randint(1,10)
    num2=eval(input('enter the num2:'))
    if num1==num2:
        print("won")
    else:
        print("loss")
game1()
# Out:
# enter the num2: 5
# loss

# %% [markdown]
# **case-1**
#
# - step1:define the function
#
# - step2:call the function
#
# - step3:run the function

# %%
def average(n1,n2,n3=40):
    print('n1:'n1)
    print('n2:'n3)
    print('n3:'n3)
    avg=(n1+n2+n3)/3
    print(f"the avg of

# %%
def add (a,b,c):
    print('a:',a)
    print('b:',b)
    print('c:',c)
    d=a+b+c
    print(d)

add(10,20,100)
# Out:
# a: 10
# b: 20
# c: 100
# 130

# %%
def add (a,b,c=50):
    print('a:',a)
    print('b:',b)
    print('c:',c)
    c=900
    d=a+b+c
    print(d)
c=400
add(10,20,100)
# Out:
# a: 10
# b: 20
# c: 100
# 930

# %% [markdown]
# **local variables vs global variables**
#
# - local variables are used inside the function
#
# - global variables are used outside the functions
#
# - global variables can be

# %%
**note**

- local variable can not be used outside the function

-

# %% [markdown]
# **how to use local variable ouside the functiion call**

# %% [markdown]
# - local variables can use outside the function in two ways
#
# - by making local variable as global by uing global
#
# - by using return statement also

# %%
def sum(a,b):
    global add,sub
    add=a+b
    sub=a-b
    print(add,sub)

sum(20,30)
# Out:
# 50 -10

# %% [markdown]
# **unbound local error**
#
# - unbound local variable means the variable is not defined
#
# - thet variable is used as both input and output insid the function

# %%
def fun1():
    a=10
    b=b+a
    print(b)

fun1()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 6
#       3     b=b+a
#       4     print(b)
# ----> 6 fun1()
#
# Cell In[5], line 3, in fun1()
#       1 def fun1():
#       2     a=10
# ----> 3     b=b+a
#       4     print(b)
#
# UnboundLocalError: cannot access local variable 'b' where it is not associated with a value

# %%
def fun2():
    a=10
    c=b+a
    print(c)

fun1()
# Out:
# 20

# %%
a=10
b=b+a

# %% [markdown]
# **return statemen**
#
# - till now above we created a functions with print statements in order to
#
# - the function outputs we are not able to use outside the function
#
# - because it is a local  variable
#
# - one method we used id **global**
#
# - another method is return statement
#
# - return means some thing we are recieving
#
# - print means only we can see the answer

# %%
def add(a,b):
    c=a+b
    return(c)
add(20,30)
# Out:
# 50

# %%
c
# Out:
# 50

# %%
def add(a,b):
    c=a+b
    return(c)
vall=add(20,30)

# %%
vall
# Out:
# 50

# %% [markdown]
# **global vs return**
#
# - global keyword used for wee can take inside variable to oputside the function
#
# - return can return any value out side the function
#
# - **the value you return can also be used to another notebook**

# %% [markdown]
# **function in function**

# %%
def greet1():
    print("hello good night")

def greet2():
    print("hello good night")

greet1()
greet2()
# Out:
# hello good night
# hello good night

# %%
def greet1():
    print("hello good morning")

def greet2():
    print("greet1 function starts")
    greet1()
    print("hello good night")

greet2()
# Out:
# greet1 function starts
# hello good morning
# hello good night

# %%
def greet1():
    print("greet2 function starts")
    greet2()
    print("hello good morning")

def greet2():
    print("greet1 function starts")
    greet1()
    print("hello good night")

greet2()
# Out:
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# greet1 function starts
# greet2 function starts
# ...

# %%
def outside_function(name):
    def inside_function():
        print(f'hello {name} good morning')

outside_function()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 5
#       2     def inside_function():
#       3         print(f'hello {name} good morning')
# ----> 5 outside_function()
#
# TypeError: outside_function() missing 1 required positional argument: 'name'

# %%
# error code 
def inside_function():
        print(f'hello {name} good morning')
    # we need to sense here 
    #name is not defined not only globally
    # id i call this function def i will get error
def outside_function(name):
    inside_function()

outside_function('python')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 9
#       6 def outside_function(name):
#       7     inside_function()
# ----> 9 outside_function('python')
#
# Cell In[63], line 7, in outside_function(name)
#       6 def outside_function(name):
# ----> 7     inside_function()
#
# Cell In[63], line 2, in inside_function()
#       1 def inside_function():
# ----> 2         print(f'hello {name} good morning')
#
# NameError: name 'name' is not defined

# %%
# working code 
def inside_function(name):
        print(f'hello {name} good morning')
   # is the variable defined anywhere
    
def outside_function(name):
    inside_function(name)

outside_function('python')
# Out:
# hello python good morning

# %%
def outside_function(name):
    def inside_function(name):
        print(f'hello {name} good morning')
    inside_function('naresh')
    
outside_function('naresh')
# Out:
# hello naresh good morning

# %%
def add(a,b):
    print(a+b)
add(10,20)
# Out:
# 30

# %%
def math():
    def add(a,b):
        print(a+b)
    add(10,20)
math()
# Out:
# 30

# %%
def math1():
    def math():
        def add(a,b):
            print(a+b)
        add(10,20)
     math()
math1()
# Out:
#   File <string>:6
#     math()
#           ^
# IndentationError: unindent does not match any outer indentation level
